# %% [markdown]
# <a href="https://colab.research.google.com/github/2301sneha/bootcamp-project/blob/main/HRdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ed8a586-2da8-46c2-b770-368c50a03911" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ed8a586-2da8-46c2-b770-368c50a03911">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HR_Employee_Attrition-1.csv to HR_Employee_Attrition-1.csv

# %%
#Store the data into a data frame
df = pd.read_csv('HR_Employee_Attrition-1.csv')


#print the first 7 rows of data
df.head(7)
# Out:
#    EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0               1       Yes   41      Travel_Rarely       1102
# 1               2        No   49  Travel_Frequently        279
# 2               3       Yes   37      Travel_Rarely       1373
# 3               4        No   33  Travel_Frequently       1392
# 4               5        No   27      Travel_Rarely        591
# 5               6        No   32  Travel_Frequently       1005
# 6               7        No   59      Travel_Rarely       1324
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# ...

# %%
# get the number of rows and cols
df.shape
# Out:
# (2940, 35)

# %%
# get the column data types
df.dtypes
# Out:
# EmployeeNumber               int64
# Attrition                   object
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#Get a count of the empty values for each column
df.isna().sum()
# Out:
# EmployeeNumber              0
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#check for any missing / null values in the data 
df.isnull().values.any()
# Out:
# False

# %%
#view some statistics 
df.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     2940.000000  2940.000000  2940.000000       2940.000000
# mean      1470.500000    36.923810   802.485714          9.192517
# std        848.849221     9.133819   403.440447          8.105485
# min          1.000000    18.000000   102.000000          1.000000
# 25%        735.750000    30.000000   465.000000          2.000000
# 50%       1470.500000    36.000000   802.000000          7.000000
# 75%       2205.250000    43.000000  1157.000000         14.000000
# max       2940.000000    60.000000  1499.000000         29.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  2940.000000         2940.0              2940.000000  2940.000000
# mean      2.912925            1.0                 2.721769    65.891156
# std       1.023991            0.0                 1.092896    20.325969
# min       1.000000            1.0                 1.000000    30.000000
# ...

# %%
# get a count of the number of employees that stayed and left the company
df['Attrition'].value_counts()
# Out:
# No     2466
# Yes     474
# Name: Attrition, dtype: int64

# %%
#visualize the number of employees that stayed and left the company
sns.countplot(df['Attrition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# This is the percentage if we just guessed no of attrition

(1233-237)/1233
# Out:
# 0.8077858880778589

# %%
# show the number of employees that left and stayed by age
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x='Age',hue='Attrition',data=df,palette='colorblind')

# %%
# Print all of the data types and their unique values
for column in df.columns:
  if df[column].dtype == object:
    print(str(column) + ':'+ str(df[column].unique()))
    print(df[column].value_counts())
    print('__________________________________________________________________________')
# Out:
# Attrition:['Yes' 'No']
# No     2466
# Yes     474
# Name: Attrition, dtype: int64
# __________________________________________________________________________
# BusinessTravel:['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        2086
# Travel_Frequently     554
# Non-Travel            300
# Name: BusinessTravel, dtype: int64
# __________________________________________________________________________
# Department:['Sales' 'Research & Development' 'Human Resources']
# Research & Development    1922
# Sales                      892
# Human Resources            126
# Name: Department, dtype: int64
# __________________________________________________________________________
# EducationField:['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       1212
# Medical              928
# Marketing            318
# Technical Degree     264
# Other                164
# Human Resources       54
# ...

# %%
#Remove some useless columns
df = df.drop('Over18', axis = 1)
df = df.drop('EmployeeNumber', axis=1)
df = df.drop('StandardHours', axis=1)
df = df.drop('EmployeeCount', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-a90e57dfbf3e> in <module>()
#       1 #Remove some useless columns
# ----> 2 df = df.drop('Over18', axis = 1)
#       3 df = df.drop('EmployeeNumber', axis=1)
#       4 df = df.drop('StandardHours', axis=1)
#       5 df = df.drop('EmployeeCount', axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
#Get the correlation
df.corr()
# Out:
#                           EmployeeNumber       Age  DailyRate  \
# EmployeeNumber                  1.000000 -0.005175  -0.025742
# Age                            -0.005175  1.000000   0.010661
# DailyRate                      -0.025742  0.010661   1.000000
# DistanceFromHome                0.016464 -0.001686  -0.004985
# Education                       0.020950  0.208034  -0.016806
# EmployeeCount                        NaN       NaN        NaN
# EnvironmentSatisfaction         0.008712  0.010146   0.018355
# HourlyRate                      0.017377  0.024287   0.023381
# JobInvolvement                 -0.003552  0.029820   0.046135
# JobLevel                       -0.009020  0.509604   0.002966
# JobSatisfaction                -0.022970 -0.004892   0.030571
# MonthlyIncome                  -0.007188  0.497855   0.007707
# MonthlyRate                     0.006177  0.028051  -0.032182
# NumCompaniesWorked             -0.000345  0.299635   0.038153
# ...

# %%
#Visualize the correlation
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(),annot=True,fmt='.0%')

# %%
#Transform the data
#Transform non-numerical into numerical col
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
  if df[column].dtype == np.number:
    continue
  df[column] = LabelEncoder().fit_transform(df[column])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.

# %%
#Create a new column
df['Age_Years'] = df['Age']

# %%
#Drop the age column
df = df.drop('Age', axis = 1)

# %%
#Show the dataframe
df
# Out:
#       EmployeeNumber  Attrition  BusinessTravel  DailyRate  Department  \
# 0                  0          1               2        624           2
# 1                  1          0               1        113           1
# 2                  2          1               2        805           1
# 3                  3          0               1        820           1
# 4                  4          0               2        312           1
# ...              ...        ...             ...        ...         ...
# 2935            2935          0               1        494           1
# 2936            2936          0               2        327           1
# 2937            2937          0               2         39           1
# 2938            2938          0               1        579           2
# 2939            2939          0               2        336           1
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# ...

# %%
# split the data
x = df.iloc[:, 1:df.shape[1]].values
Y = df.iloc[:,0].values

# %%
#Split the data into 75% training and 25% testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-2aa8920fe8ce> in <module>()
#       1 #Split the data into 75% training and 25% testing
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0 )
#
# NameError: name 'X' is not defined

# %%
#Use the Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-695c00e41fbd> in <module>()
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
# ----> 4 forest.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
#Get the accuracy on the trainig data-set
forest.score(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-7f3e860a2923> in <module>()
#       1 #Get the accuracy on the trainig data-set
# ----> 2 forest.score(X_train,Y_train)
#
# NameError: name 'X_train' is not defined

# %%
#Show the confusion matrix and accurarcy score for the model on the test data
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(Y_test, forest.predict(X_test))
TN = cm[0][0]
TP = cm[1][1]
FP = cm[0][1]

print(cm)
print('Model Testing Accurarcy = {}'.format(TP+TN)/(TP+TN+FN+FP))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3ad909ed8d0d> in <module>()
#       2 from sklearn.metrics import confusion_matrix
#       3
# ----> 4 cm=confusion_matrix(Y_test, forest.predict(X_test))
#       5 TN = cm[0][0]
#       6 TP = cm[1][1]
#
# NameError: name 'Y_test' is not defined

# %%
#Show the confusion matrix and accuracy score for the model on the test data
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, forest.predict(X_test))

TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

print(cm)
print('Model Testing Accuracy = {}' .format( (TP + TN) / (TP + TN + FN + FP) ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-7b72c9eb68e1> in <module>()
#       2 from sklearn.metrics import confusion_matrix
#       3
# ----> 4 cm = confusion_matrix(Y_test, forest.predict(X_test))
#       5
#       6 TN = cm[0][0]
#
# NameError: name 'Y_test' is not defined
